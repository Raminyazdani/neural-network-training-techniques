# %% [markdown]
# # Neural Network Training Techniques
#
# ## Batch Normalization Study
#
# This notebook demonstrates the impact of batch normalization on neural network training. We will implement and compare two neural networks:
#
# 1. A baseline feed-forward neural network
# 2. An enhanced network with batch normalization layers
#
# Both networks will be trained on the FashionMNIST dataset.
